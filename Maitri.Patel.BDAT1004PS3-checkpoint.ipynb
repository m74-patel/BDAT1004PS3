# %% [markdown]
# Question 1

# %%
import pandas as pd

# %%
users=pd.read_csv('age.csv')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# Mean age per occupation

# %%
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# Male ratio per occupation and sort it from the most to the least

# %%
users['is_male'] = users.gender.apply(lambda x: True if x == 'M' else False)
users.is_male
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 938    False
# 939     True
# 940     True
# 941    False
# 942     True
# Name: is_male, Length: 943, dtype: bool

# %%
(users.groupby('occupation').is_male.sum() / users.groupby('occupation').gender.count()).sort_values(ascending = False)
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# dtype: float64

# %% [markdown]
# the minimum and maximum ages

# %%
print(users.groupby('occupation').age.min())
print(users.groupby('occupation').age.max())
# Out:
# occupation
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# Name: age, dtype: int64
# occupation
# administrator    70
# artist           48
# doctor           64
# educator         63
# engineer         70
# entertainment    50
# executive        69
# healthcare       62
# homemaker        50
# lawyer           53
# librarian        69
# marketing        55
# none             55
# other            64
# programmer       63
# retired          73
# salesman         66
# scientist        55
# student          42
# technician       55
# writer           60
# ...

# %% [markdown]
# Mean age

# %%
users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
#  percentage of women and men in every occupation

# %%
gender_occup = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})
occup_count = users.groupby(['occupation']).count()

occup_gender = gender_occup.div(occup_count, level = "occupation")
occup_gender.loc[:, 'gender']
# Out:
# occupation     gender
# administrator  F         0.455696
#                M         0.544304
# artist         F         0.464286
#                M         0.535714
# doctor         M         1.000000
# educator       F         0.273684
#                M         0.726316
# engineer       F         0.029851
#                M         0.970149
# entertainment  F         0.111111
#                M         0.888889
# executive      F         0.093750
#                M         0.906250
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         F         0.166667
#                M         0.833333
# librarian      F         0.568627
#                M         0.431373
# marketing      F         0.384615
#                M         0.615385
# none           F         0.444444
#                M         0.555556
# other          F         0.342857
#                M         0.657143
# ...

# %% [markdown]
# Question 2

# %%
import pandas as pd
import numpy as np

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Goal columns

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# Team participated in Euro 2021

# %%
euro12.Team.nunique()
# Out:
# 16

# %% [markdown]
# Number of column

# %%
euro12.shape[1]
# Out:
# 35

# %% [markdown]
# Assign a columns Team, Yellow Cards and Red Cards to dataframe called discipline

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(by=['Red Cards', 'Yellow Cards'], inplace = True)
discipline
# Out:
# C:\Users\maitr\AppData\Local\Temp\ipykernel_19024\4264773076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discipline.sort_values(by=['Red Cards', 'Yellow Cards'], inplace = True)
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# ...

# %% [markdown]
# mean Yellow Cards given per Team

# %%
discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# Filter teams that scored more than 6 goals

# %%
euro12[euro12['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# the teams that start with G

# %%
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# first 7 columns

# %%
euro12.iloc[: , 0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# all columns except the last 3

# %%
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# Question 3

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 3 series

# %%
x = pd.Series(np.random.randint(1, high=5, size=100, dtype='l'))
y = pd.Series(np.random.randint(1, high=4, size=100, dtype='l'))
z = pd.Series(np.random.randint(10000, high=30001, size=100, dtype='l'))

print(x,y,z)
# Out:
# 0     3
# 1     1
# 2     2
# 3     3
# 4     2
#      ..
# 95    1
# 96    2
# 97    2
# 98    4
# 99    1
# Length: 100, dtype: int32 0     2
# 1     3
# 2     3
# 3     2
# 4     1
#      ..
# 95    3
# 96    1
# 97    3
# 98    2
# 99    1
# Length: 100, dtype: int32 0     26532
# 1     16722
# 2     21267
# 3     24458
# 4     10886
#       ...
# 95    19343
# 96    29328
# 97    25059
# 98    18143
# 99    19497
# Length: 100, dtype: int32

# %% [markdown]
# creating dataframe

# %%
dataframe = pd.concat([x,y,z], axis=1)
dataframe
# Out:
#     0  1      2
# 0   3  2  26532
# 1   1  3  16722
# 2   2  3  21267
# 3   3  2  24458
# 4   2  1  10886
# .. .. ..    ...
# 95  1  3  19343
# 96  2  1  29328
# 97  2  3  25059
# 98  4  2  18143
# 99  1  1  19497
#
# [100 rows x 3 columns]

# %% [markdown]
# Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
dataframe.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
dataframe.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      3       2            26532
# 1      1       3            16722
# 2      2       3            21267
# 3      3       2            24458
# 4      2       1            10886

# %% [markdown]
# Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigcolumn = pd.concat([x,y,z], axis=0)

bigcolumn = bigcolumn.to_frame()
print(type(bigcolumn))

bigcolumn
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         0
# 0       3
# 1       1
# 2       2
# 3       3
# 4       2
# ..    ...
# 95  19343
# 96  29328
# 97  25059
# 98  18143
# 99  19497
#
# [300 rows x 1 columns]

# %%
len(bigcolumn)
# Out:
# 300

# %%
bigcolumn.reset_index(drop=True, inplace=True)
bigcolumn
# Out:
#          0
# 0        3
# 1        1
# 2        2
# 3        3
# 4        2
# ..     ...
# 295  19343
# 296  29328
# 297  25059
# 298  18143
# 299  19497
#
# [300 rows x 1 columns]

# %% [markdown]
# Question 4

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
data=pd.read_csv("wind.txt",sep ="\s+")
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# Question 5

# %%
import pandas as pd

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.shape[0]
# Out:
# 4622

# %%
chipo.shape[1]
# Out:
# 5

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %%
chipo.item_name.unique().shape[0]
# Out:
# 50

# %%
chipo.choice_description.value_counts().head()
# Out:
# [Diet Coke]                                                                          134
# [Coke]                                                                               123
# [Sprite]                                                                              77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]     40
# Name: choice_description, dtype: int64

# %%
chipo.quantity.sum()
# Out:
# 4972

# %%
def num_float(x):
    return float(x[1:-1])
chipo.item_price = chipo.item_price.apply(num_float)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
chipo.item_price.sum()
# Out:
# 34500.16

# %%
chipo.order_id.value_counts().shape[0]
chipo.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75

# %%
order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped['quantity'].mean()
# Out:
# 2.711014176663032

# %%
chipo['unit_price'] = (chipo['item_price'] / chipo['quantity'])
new = chipo[['item_name', 'choice_description', 'unit_price']]
new.sort_values(by='unit_price', ascending=False)
# Out:
#                 item_name                                 choice_description  \
# 2442  Barbacoa Salad Bowl  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
# 2957     Steak Salad Bowl  [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...
# 613      Steak Salad Bowl  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 2401     Steak Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Guaca...
# 281      Steak Salad Bowl  [Tomatillo Red Chili Salsa, [Black Beans, Chee...
# ...                   ...                                                ...
# 378           Canned Soda                                     [Mountain Dew]
# 1805          Canned Soda                                           [Sprite]
# 2520          Canned Soda                                        [Coca Cola]
# 2981        Bottled Water                                                NaN
# 646           Canned Soda                                           [Sprite]
#
#       unit_price
# 2442       11.89
# ...

# %% [markdown]
# Question 6

# %% [markdown]
# Question 6

# %%
import pandas as pd

# %%
total_number=pd.read_csv('us-marriages-divorces-1867-2014.csv')

# %%
total_number.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure()

total_number.plot('Year',y=['Marriages','Divorces'])
plt.show()

# %% [markdown]
# Question 7

# %%
import pandas as pd
import matplotlib. pyplot as mb

# %%
us_marriage_divorce = pd.read_csv('us-marriages-divorces-1867-2014.csv')
us_marriage_divorce = us_marriage_divorce[
    us_marriage_divorce['Year'].apply(lambda x: x in [1900, 1950, 2000])]

years = us_marriage_divorce['Year'].values
marriages_per_capita = us_marriage_divorce['Marriages_per_1000'].values
divorces_per_capita = us_marriage_divorce['Divorces_per_1000'].values
mb.bar(years-2,marriages_per_capita,width=15)
mb.bar(years-2,divorces_per_capita,width=15)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# Question 8

# %%
holl= pd.read_csv('actor_kill_counts.csv')
holl
actor_names = holl['Actor'].values
kill_counts = holl['Count'].values
mb.barh(actor_names,kill_counts)
mb.show()

# %% [markdown]
# Question 10

# %%
arcade_revenue_cs = pd.read_csv("arcade-revenue-vs-cs-doctorates.csv")
arcade_revenue = arcade_revenue_cs['Total Arcade Revenue (billions)'].values
cs_doctorates_awarded = arcade_revenue_cs[
    'Computer Science Doctorates Awarded (US)'].values
mb.scatter(arcade_revenue,cs_doctorates_awarded)
